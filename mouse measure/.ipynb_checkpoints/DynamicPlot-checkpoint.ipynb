# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
def plt_dynamic(x, y, ax, colors=['b']):
    ax.set_xlim(x[0], x[-1])
    for color in colors:        
        ax.plot(x, y, color)
    fig.canvas.draw()

# %%
fig,(ax, ax2) = plt.subplots(2,1,sharey="none")
ax.set_xlabel('X') ; ax.set_ylabel('Y')
ax2.set_xlabel('X') ; ax2.set_ylabel('Y')
ax.set_xlim(0,360) ; ax.set_ylim(-1,1)
xs, ys = [], []
plt.tight_layout()

# this is any loop for which you want to plot dynamic updates.
# in my case, I'm plotting loss functions for neural nets

#for x in range(360):
#    y = np.sin(x*np.pi/180)
#    xs.append(x)
#    ys.append(y)
#    if x % 30 == 0:
#        plt_dynamic(xs, ys, ax)
#        time.sleep(.2)
#plt_dynamic(xs, ys, ax)

x=0
while x<1000:
    y = np.sin(x*np.pi/180)
    xs.append(x)
    x += 1
    ys.append(y)
    if x % 30 == 0:        
        if len(xs) > 360:
            plt_dynamic(xs[-360:-1], ys[-360:-1], ax)
        else:
            plt_dynamic(xs, ys, ax)
        time.sleep(.2)

ax2.plot(xs, ys)
ax2.set_xlabel('X') ; ax2.set_ylabel('Y')
fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">
